# %% [markdown]
# # 🚀 Floor Plan Training - GitHub Direct Clone
#
# **Fastest method - No ZIP upload!**

# %%
# Step 1: Check GPU
# !nvidia-smi

# %%
# Step 2: Install packages
# !pip install -q torch torchvision opencv-python pillow numpy scipy scikit-learn tqdm

# %%
# Step 3: Clone GitHub repo
# !git clone https://github.com/Harshb1112/ai-construction-takeoff.git
# %cd ai-construction-takeoff
# !ls -la models/

# %%
# Step 4: Mount Google Drive (to save trained model)
from google.colab import drive
drive.mount('/content/drive')

# Create output directory in Drive
# !mkdir -p /content/drive/MyDrive/floor_plan_models

# %%
# Step 5: Check dataset
import os
import glob

# Check if training data exists
training_script = 'models/Model_training.py'
if os.path.exists(training_script):
    print(f"✅ Training script found: {training_script}")
else:
    print(f"❌ Training script not found: {training_script}")

# List all Python files in models
print("\nAvailable files in models/:")
# !ls -lh models/*.py

# %%
# Step 6: Start training
# !python models/Model_training.py

# %%
# Step 7: Save model to Google Drive
# !cp floor_plan_model.pth /content/drive/MyDrive/floor_plan_models/floor_plan_model_$(date +%Y%m%d_%H%M%S).pth
# !cp -r models/model_output /content/drive/MyDrive/floor_plan_models/

print("✅ Model saved to Google Drive: MyDrive/floor_plan_models/")
print("\nYou can access it from your Google Drive!")

# %%
# Step 8: View training results
import json
import matplotlib.pyplot as plt

try:
    with open('models/model_output/retrain_history.json', 'r') as f:
        history = json.load(f)
    
    # Plot training curves
    plt.figure(figsize=(14, 5))
    
    plt.subplot(1, 3, 1)
    plt.plot(history['train_loss'], label='Train Loss', linewidth=2)
    plt.plot(history['val_loss'], label='Val Loss', linewidth=2)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(fontsize=10)
    plt.title('Training Loss', fontsize=14, fontweight='bold')
    plt.grid(True, alpha=0.3)
    
    plt.subplot(1, 3, 2)
    plt.plot(history['val_miou'], label='Val mIoU', color='green', linewidth=2)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('mIoU', fontsize=12)
    plt.legend(fontsize=10)
    plt.title('Validation mIoU', fontsize=14, fontweight='bold')
    plt.grid(True, alpha=0.3)
    
    plt.subplot(1, 3, 3)
    plt.plot(history['learning_rate'], label='Learning Rate', color='orange', linewidth=2)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('LR', fontsize=12)
    plt.legend(fontsize=10)
    plt.title('Learning Rate Schedule', fontsize=14, fontweight='bold')
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig('/content/drive/MyDrive/floor_plan_models/training_curves.png', dpi=150)
    plt.show()
    
    print(f"\n📊 Training Summary:")
    print(f"Best mIoU: {max(history['val_miou']):.4f}")
    print(f"Final Train Loss: {history['train_loss'][-1]:.4f}")
    print(f"Final Val Loss: {history['val_loss'][-1]:.4f}")
    print(f"Total Epochs: {len(history['train_loss'])}")
    
except FileNotFoundError:
    print("Training history not found. Make sure training completed successfully.")

# %%
# Step 9: Download model (optional - already saved to Drive)
from google.colab import files
files.download('floor_plan_model.pth')
